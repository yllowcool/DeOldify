# %% [markdown]
# ## Stable Model Training (Large Batch/Limited GPU Memory Support)

# %% [markdown]
# ## IMPORTANT: Training has -not- been verified by myself for this notebook ~jantic

# %% [markdown]
# ### This notebook has been written to take advantage of the Large Model Support technology created by IBM.

# %% [markdown]
# ### Information on Large Model Support
# Large Model Support (LMS) is a feature provided in IBM Watson Machine Learning - Community Edition (WML-ce) PyTorch > V1.1.0 that allows the successful training of deep learning models that would otherwise exhaust GPU memory and abort with “out-of-memory” errors. LMS manages this oversubscription of GPU memory by temporarily swapping tensors to host memory when they are not needed. One or more elements of a deep learning model can lead to GPU memory exhaustion.
#
# Requires the use of IBM WML-ce (Available here: https://www.ibm.com/support/knowledgecenter/en/SS5SF7_1.7.0/welcome/welcome.html)
#
# Further Reading on PyTorch with Large Model Support: https://www.ibm.com/support/knowledgecenter/en/SS5SF7_1.7.0/navigation/wmlce_getstarted_pytorch.html#wmlce_getstarted_pytorch__lms_section
#
#
# #### NOTE:
# Using Large Model Support (LMS) will allow you to train the DeOldify models with a GPU that generally would not be suitable (e.g. GTX 1070 8Gb). A penalty to using LMS on x86_64 is that you will notice increased training times, due to the lack of a high bandwidth NVLink between the GPU and CPU.
#
# If you are training on a PPC64LE system with NVLink (e.g. IBM AC922), then you will NOT suffer any penalty when using LMS and you can also increase the batch size to decrease the overall training times.

# %% [markdown]
# ### Changes made
#
# 1. Larger ResNet backend (152 vs 101)
# 2. Easily Train on existing models (aka Tranfer Learn)
# 3. Easily Train via Half Precision
# 4. Increased Progressive Resizing to 512px
# 5. WIP: Train using EfficientNet backend (b7). You can optionally train to 600px if using EfficientNet

# %% [markdown]
# #### NOTES:
# * This is "NoGAN" based training, described in the DeOldify readme.
# * This model prioritizes stable and reliable renderings.  It does particularly well on portraits and landscapes.  It's not as colorful as the artistic model.

# %%
#NOTE:  This must be the first call in order to work properly!
from deoldify import device
from deoldify.device_id import DeviceId
#choices:  CPU, GPU0...GPU7
device.set(device=DeviceId.GPU0)
# Out:
# <DeviceId.GPU0: 0>

# %%
# Dockerfile installs this but for some reason it's not loaded
# !pip install tensorboardx==1.6.0
# !pip install efficientnet-pytorch
# Out:
# Collecting tensorboardx==1.6.0
#   Using cached tensorboardX-1.6-py2.py3-none-any.whl (129 kB)
# Requirement already satisfied: protobuf>=3.2.0 in /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages (from tensorboardx==1.6.0) (3.8.0)
# Requirement already satisfied: numpy in /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages (from tensorboardx==1.6.0) (1.17.4)
# Requirement already satisfied: six in /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages (from tensorboardx==1.6.0) (1.13.0)
# Requirement already satisfied: setuptools in /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages (from protobuf>=3.2.0->tensorboardx==1.6.0) (46.0.0.post20200309)
# Installing collected packages: tensorboardx
# Successfully installed tensorboardx-1.6
# Processing /home/cecuser/.cache/pip/wheels/1c/07/d1/ff77968842daae1dde944173a8e8a7be193646d37842f13b24/efficientnet_pytorch-0.6.3-py3-none-any.whl
# Requirement already satisfied: torch in /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages (from efficientnet-pytorch) (1.3.1)
# Requirement already satisfied: numpy in /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages (from torch->efficientnet-pytorch) (1.17.4)
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.6.3

# %%
resnet152_backend=True

# %%
import tensorflow as tf
import datetime
import os
import fastai
from fastai import *
from fastai.vision import *
from fastai.callbacks.tensorboard import *
from fastai.vision.gan import *
if resnet152_backend == True:
    from deoldify.generatorsResNet152 import *
else:
    from deoldify.generators import *
# Comment out above and Uncomment below to Load EfficientNet instead of ResNet101 for generators (Work in Progress)
# from deoldify.generatorsEFFNET import *
from deoldify.critics import *
from deoldify.dataset import *
from deoldify.loss import *
from deoldify.save import *
from PIL import Image, ImageDraw, ImageFont
from PIL import ImageFile

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Activate Large Model Support for PyTorch

# %%
import shutil

# %%
# Set limit of GPU memory used before swapping tensors to host memory. 
# max_gpu_mem = 29

def gb_to_bytes(gb):
    return gb*1024*1024*1024

# Enable PyTorch LMS
torch.cuda.set_enabled_lms(True)

# Set LMS limit
# torch.cuda.set_limit_lms(gb_to_bytes(max_gpu_mem))

# %%
# Check LMS is enabled
torch.cuda.get_enabled_lms()
# Out:
# True

# %%
# Check LMS Limit has been set
torch.cuda.get_limit_lms()
# Out:
# 0

# %%
# Enable Half Precision (fp16) - https://docs.fast.ai/callbacks.fp16.html
hp_enable = False

# Load existing Generator model
load_existing_gen_model = False

# Load existing Critic model
load_existing_critic_model = False

# %%
# Path to Training Data
path = Path('/home/cecuser/imageset/train')
path_hr = path

# Path to Validation Data
path_val = '/home/cecuser/imageset/val'

# Path to Black and White images
path_bandw = Path('/home/cecuser/generated')
path_lr = path_bandw/'bandw'

# Name of Model
proj_id = 'ColorizeStableLMS'

# Name of Generator
if load_existing_gen_model == False:
        gen_name = proj_id + '_gen'
else:
        # Path to existing Pre-Trained Model
        model_path = '/mnt/datasets/deoldify-pretrained-models/pretrain_gen-weights/'
        gen_name = model_path + proj_id + '_PretrainOnly_gen'

pre_gen_name = gen_name + '_0'

# Name of Critic
crit_name = proj_id + '_crit'

# Name of Generated Images folder, located within Training Data folder
name_gen = proj_id + '_image_gen'
path_gen = path/name_gen

# Path to tensorboard data
TENSORBOARD_PATH = Path('/home/cecuser/tensorboard/' + proj_id)

nf_factor = 2
pct_start = 1e-8

# Specify Pre-Trained model
gen_old_checkpoint_name = pre_gen_name

# %%
def get_data(bs:int, sz:int, keep_pct:float):
    return get_colorize_data(sz=sz, bs=bs, crappy_path=path_lr, good_path=path_hr, 
                             random_seed=None, keep_pct=keep_pct)

def get_crit_data(classes, bs, sz):
    src = ImageList.from_folder(path, include=classes, recurse=True).split_by_rand_pct(0.1, seed=42)
    ll = src.label_from_folder(classes=classes)
    data = (ll.transform(get_transforms(max_zoom=2.), size=sz)
           .databunch(bs=bs).normalize(imagenet_stats))
    return data

def create_training_images(fn,i):
    dest = path_lr/fn.relative_to(path_hr)
    dest.parent.mkdir(parents=True, exist_ok=True)
    img = PIL.Image.open(fn).convert('LA').convert('RGB')
    img.save(dest)  
    
def save_preds(dl):
    i=0
    names = dl.dataset.items
    
    for b in dl:
        preds = learn_gen.pred_batch(batch=b, reconstruct=True)
        for o in preds:
            o.save(path_gen/names[i].name)
            i += 1
    
def save_gen_images():
    if path_gen.exists(): shutil.rmtree(path_gen)
    path_gen.mkdir(exist_ok=True)
    data_gen = get_data(bs=bs, sz=sz, keep_pct=0.085)
    save_preds(data_gen.fix_dl)
    PIL.Image.open(path_gen.ls()[0])

# %% [markdown]
# ## Create black and white training images

# %% [markdown]
# Only runs if the directory isn't already created.

# %%
if not path_lr.exists():
    il = ImageList.from_folder(path_hr)
    parallel(create_training_images, il.items)
# Out:
# /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/PIL/Image.py:987: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")

# %%
# List total number of B&W images
total_bw = len(list(path_lr.rglob('*.*')))
print('Total B&W Images:', total_bw)
# Out:
# Total B&W Images: 750

# %% [markdown]
# ## Pre-train generator

# %% [markdown]
# #### NOTE
# Most of the training takes place here in pretraining for NoGAN.  The goal here is to take the generator as far as possible with conventional training, as that is much easier to control and obtain glitch-free results compared to GAN training.

# %% [markdown]
# ### 64px

# %%
bs=160 # This can be increased if using PyTorch LMS. Training can be slower when using x86_64. PPC64LE with NVLink (e.g. Power8 / Power9) does not suffer this training penalty
sz=64
keep_pct=1.0

# %%
data_gen = get_data(bs=bs, sz=sz, keep_pct=keep_pct)

# %%
if load_existing_gen_model == True and hp_enable == True:
        learn_gen = gen_learner_wide(data=data_gen, gen_loss=FeatureLoss(), nf_factor=nf_factor).load(gen_old_checkpoint_name, with_opt=False).to_fp16()
elif load_existing_gen_model == True:
        learn_gen = gen_learner_wide(data=data_gen, gen_loss=FeatureLoss(), nf_factor=nf_factor).load(gen_old_checkpoint_name, with_opt=False)
elif hp_enable == True:
        learn_gen = gen_learner_wide(data=data_gen, gen_loss=FeatureLoss(), nf_factor=nf_factor).to_fp16()
else:
        learn_gen = gen_learner_wide(data=data_gen, gen_loss=FeatureLoss(), nf_factor=nf_factor)

# %%
learn_gen.callback_fns.append(partial(ImageGenTensorboardWriter, base_dir=TENSORBOARD_PATH, name='GenPreTrain-64px'))

# %%
learn_gen.fit_one_cycle(30, pct_start=0.8, max_lr=slice(1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>7.095348</td>
#       <td>6.720932</td>
#       <td>04:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.206686</td>
#       <td>6.779354</td>
#       <td>03:48</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.165761</td>
#       <td>6.944207</td>
#       <td>03:47</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.075704</td>
#       <td>6.954116</td>
#       <td>03:57</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.970150</td>
#       <td>6.849256</td>
#       <td>03:46</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>6.855812</td>
#       <td>6.602319</td>
#       <td>03:49</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>6.736345</td>
#       <td>6.236309</td>
#       <td>03:40</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>6.615746</td>
#       <td>5.908800</td>
#       <td>03:46</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>6.489696</td>
#       <td>5.630532</td>
#       <td>03:55</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>6.354421</td>
#       <td>5.427392</td>
#       <td>03:46</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>6.212759</td>
#       <td>5.170516</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>6.061673</td>
#       <td>4.963140</td>
#       <td>03:50</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>5.913648</td>
#       <td>4.745131</td>
#       <td>03:47</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>5.763182</td>
#       <td>4.559336</td>
#       <td>03:45</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>5.614008</td>
#       <td>4.393107</td>
#       <td>03:48</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>5.468135</td>
#       <td>4.166339</td>
#       <td>03:50</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>5.323476</td>
#       <td>3.956204</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>5.176334</td>
#       <td>3.764975</td>
#       <td>03:48</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>5.030751</td>
#       <td>3.544924</td>
#       <td>04:04</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>4.892703</td>
#       <td>3.436786</td>
#       <td>04:10</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>4.757338</td>
#       <td>3.370703</td>
#       <td>03:49</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>4.628012</td>
#       <td>3.259107</td>
#       <td>03:49</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>4.501479</td>
#       <td>3.186406</td>
#       <td>03:48</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>4.381505</td>
#       <td>3.134813</td>
#       <td>03:53</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>4.272053</td>
#       <td>3.120731</td>
#       <td>03:48</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>4.168629</td>
#       <td>3.072574</td>
#       <td>03:51</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>4.075933</td>
#       <td>3.067912</td>
#       <td>03:45</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>3.989224</td>
#       <td>3.048668</td>
#       <td>03:45</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>3.908508</td>
#       <td>3.035539</td>
#       <td>03:52</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>3.834772</td>
#       <td>3.030907</td>
#       <td>03:59</td>
#     </tr>
#   </tbody>
# </table>
# /home/cecuser/DeOldify/deoldify/unet.py:202: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if ssh != up_out.shape[-2:]:
# /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/torch/onnx/utils.py:617: UserWarning: ONNX export failed on ATen operator mv because torch.onnx.symbolic_opset9.mv does not exist
#   .format(op_name, opset_version, op_name))
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/home/cecuser/anaconda3/envs/colorproj/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/cecuser/anaconda3/envs/colorproj/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/fastai/callbacks/tensorboard.py", line 234, in _queue_processor
#     request.write()
#   File "/home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/fastai/callbacks/tensorboard.py", line 424, in write
#     self.tbwriter.add_graph(model=self.model, input_to_model=self.input_to_model)
#   File "/home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/tensorboardX/writer.py", line 566, in add_graph
#     self.file_writer.add_graph(graph(model, input_to_model, verbose))
#   File "/home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/tensorboardX/pytorch_graph.py", line 235, in graph
#     _optimize_trace(trace, torch.onnx.utils.OperatorExportTypes.ONNX)
#   File "/home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/tensorboardX/pytorch_graph.py", line 175, in _optimize_trace
#     trace.set_graph(_optimize_graph(trace.graph(), operator_export_type))
#   File "/home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/tensorboardX/pytorch_graph.py", line 206, in _optimize_graph
#     graph = torch._C._jit_pass_onnx(graph, operator_export_type)
#   File "/home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/torch/onnx/__init__.py", line 174, in _run_symbolic_function
#     return utils._run_symbolic_function(*args, **kwargs)
#   File "/home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/torch/onnx/utils.py", line 618, in _run_symbolic_function
#     op_fn = sym_registry.get_registered_op(op_name, '', opset_version)
#   File "/home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/torch/onnx/symbolic_registry.py", line 91, in get_registered_op
#     return _registry[(domain, version)][opname]
# KeyError: 'mv'

# %%
learn_gen.save(pre_gen_name)

# %%
learn_gen.unfreeze()

# %%
learn_gen.callback_fns.append(partial(ImageGenTensorboardWriter, base_dir=TENSORBOARD_PATH, name='GenPreTrain-Unfreeze-64px'))

# %%
learn_gen.fit_one_cycle(20, pct_start=pct_start,  max_lr=slice(3e-7, 3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.202944</td>
#       <td>3.139060</td>
#       <td>03:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.175956</td>
#       <td>3.153437</td>
#       <td>03:55</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.142141</td>
#       <td>3.132078</td>
#       <td>03:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.118390</td>
#       <td>3.100466</td>
#       <td>03:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.101028</td>
#       <td>3.081618</td>
#       <td>03:56</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.082427</td>
#       <td>3.064630</td>
#       <td>03:52</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.068324</td>
#       <td>3.020069</td>
#       <td>03:48</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.062632</td>
#       <td>3.008368</td>
#       <td>03:56</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.051211</td>
#       <td>3.004523</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.041897</td>
#       <td>2.987401</td>
#       <td>03:54</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.030200</td>
#       <td>2.984593</td>
#       <td>03:57</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>3.022317</td>
#       <td>2.997514</td>
#       <td>03:53</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>3.014538</td>
#       <td>2.984829</td>
#       <td>03:54</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>3.006325</td>
#       <td>2.972373</td>
#       <td>03:56</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.999732</td>
#       <td>2.970860</td>
#       <td>03:48</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.990642</td>
#       <td>2.967566</td>
#       <td>03:54</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.986607</td>
#       <td>2.966498</td>
#       <td>03:54</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>2.980418</td>
#       <td>2.966215</td>
#       <td>03:50</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>2.975776</td>
#       <td>2.966368</td>
#       <td>03:48</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>2.971889</td>
#       <td>2.966757</td>
#       <td>03:48</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_gen.save(pre_gen_name)

# %% [markdown]
# ### 128px

# %%
bs=80 # This can be increased if using PyTorch LMS. Training can be slower when using x86_64. PPC64LE with NVLink (e.g. Power8 / Power9) does not suffer this training penalty
sz=128
keep_pct=1.0

# %%
learn_gen.data = get_data(sz=sz, bs=bs, keep_pct=keep_pct)

# %%
learn_gen.callback_fns.append(partial(ImageGenTensorboardWriter, base_dir=TENSORBOARD_PATH, name='GenPreTrain-128px'))

# %%
learn_gen.unfreeze()

# %%
learn_gen.fit_one_cycle(15, pct_start=pct_start, max_lr=slice(1e-7,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.393998</td>
#       <td>2.368220</td>
#       <td>03:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.427324</td>
#       <td>2.383771</td>
#       <td>02:56</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.385410</td>
#       <td>2.371017</td>
#       <td>02:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.365283</td>
#       <td>2.356097</td>
#       <td>02:38</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.349315</td>
#       <td>2.350464</td>
#       <td>02:50</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.338110</td>
#       <td>2.353956</td>
#       <td>02:42</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.327214</td>
#       <td>2.346755</td>
#       <td>02:41</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.316142</td>
#       <td>2.337620</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.309099</td>
#       <td>2.332019</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.306203</td>
#       <td>2.340539</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.302390</td>
#       <td>2.330337</td>
#       <td>02:53</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.297090</td>
#       <td>2.323150</td>
#       <td>02:45</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.292257</td>
#       <td>2.319049</td>
#       <td>02:47</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.289113</td>
#       <td>2.315871</td>
#       <td>02:42</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.288553</td>
#       <td>2.316300</td>
#       <td>02:43</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_gen.save(pre_gen_name)

# %% [markdown]
# ### 192px

# %%
bs=40 # This can be increased if using PyTorch LMS. Training can be slower when using x86_64. PPC64LE with NVLink (e.g. Power8 / Power9) does not suffer this training penalty
sz=192
keep_pct=1.0

# %%
learn_gen.data = get_data(sz=sz, bs=bs, keep_pct=keep_pct)

# %%
learn_gen.callback_fns.append(partial(ImageGenTensorboardWriter, base_dir=TENSORBOARD_PATH, name='GenPreTrain-192px'))

# %%
learn_gen.unfreeze()

# %%
learn_gen.fit_one_cycle(10, pct_start=pct_start, max_lr=slice(5e-8,5e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.038757</td>
#       <td>1.949550</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.138484</td>
#       <td>1.972682</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.092332</td>
#       <td>1.973609</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.069175</td>
#       <td>1.965356</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.059264</td>
#       <td>1.956655</td>
#       <td>02:38</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.048656</td>
#       <td>1.953401</td>
#       <td>02:34</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.041084</td>
#       <td>1.951722</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.035697</td>
#       <td>1.950817</td>
#       <td>02:30</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.029695</td>
#       <td>1.949387</td>
#       <td>02:30</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.027184</td>
#       <td>1.948984</td>
#       <td>02:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_gen.save(pre_gen_name)

# %% [markdown]
# ### 256px

# %%
bs=20 # This can be increased if using PyTorch LMS. Training can be slower when using x86_64. PPC64LE with NVLink (e.g. Power8 / Power9) does not suffer this training penalty
sz=256
keep_pct=1.0

# %%
learn_gen.data = get_data(sz=sz, bs=bs, keep_pct=keep_pct)

# %%
learn_gen.callback_fns.append(partial(ImageGenTensorboardWriter, base_dir=TENSORBOARD_PATH, name='GenPreTrain-256px'))

# %%
learn_gen.unfreeze()

# %%
learn_gen.fit_one_cycle(5, pct_start=pct_start, max_lr=slice(5e-8,5e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.841022</td>
#       <td>1.868332</td>
#       <td>02:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.862814</td>
#       <td>1.879361</td>
#       <td>02:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.852319</td>
#       <td>1.874460</td>
#       <td>02:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.849147</td>
#       <td>1.857282</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.840847</td>
#       <td>1.865747</td>
#       <td>02:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_gen.save(pre_gen_name)

# %% [markdown]
# ### 512px

# %%
bs=10 # This can be increased if using PyTorch LMS. Training can be slower when using x86_64. PPC64LE with NVLink (e.g. Power8 / Power9) does not suffer this training penalty
sz=512
keep_pct=1.0

# %%
learn_gen.data = get_data(sz=sz, bs=bs, keep_pct=keep_pct)

# %%
learn_gen.callback_fns.append(partial(ImageGenTensorboardWriter, base_dir=TENSORBOARD_PATH, name='GenPreTrain-512px'))

# %%
learn_gen.unfreeze()

# %%
learn_gen.fit_one_cycle(1, pct_start=pct_start, max_lr=slice(5e-8,5e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.581956</td>
#       <td>1.592680</td>
#       <td>05:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_gen.save(pre_gen_name)

# %% [markdown]
# ### Optional if using EfficientNet backend

# %% [markdown]
# ### 600px

# %%
# s=10 # This can be increased if using PyTorch LMS. Training can be slower when using x86_64. PPC64LE with NVLink (e.g. Power8 / Power9) does not suffer this training penalty
# sz=600
# keep_pct=1.0

# %%
# learn_gen.data = get_data(sz=sz, bs=bs, keep_pct=keep_pct)

# %%
# learn_gen.callback_fns.append(partial(ImageGenTensorboardWriter, base_dir=TENSORBOARD_PATH, name='GenPreTrain-600px'))

# %%
# learn_gen.unfreeze()

# %%
# learn_gen.fit_one_cycle(1, pct_start=pct_start, max_lr=slice(5e-8,5e-5))

# %%
# learn_gen.save(pre_gen_name)

# %% [markdown]
# ## Repeatable GAN Cycle

# %% [markdown]
# #### NOTE
# Best results so far have been based on repeating the cycle below a few times (about 5-8?), until diminishing returns are hit (no improvement in image quality).  Each time you repeat the cycle, you want to increment that old_checkpoint_num by 1 so that new check points don't overwrite the old.

# %%
old_checkpoint_num = 0
checkpoint_num = old_checkpoint_num + 1
gen_old_checkpoint_name = gen_name + '_' + str(old_checkpoint_num)
gen_new_checkpoint_name = gen_name + '_' + str(checkpoint_num)
crit_old_checkpoint_name = crit_name + '_' + str(old_checkpoint_num)
crit_new_checkpoint_name= crit_name + '_' + str(checkpoint_num)

# %% [markdown]
# ### Save Generated Images

# %%
bs=10
sz=512

# %%
learn_gen = gen_learner_wide(data=data_gen, gen_loss=FeatureLoss(), nf_factor=nf_factor).load(gen_old_checkpoint_name, with_opt=False)

# %%
save_gen_images()

# %% [markdown]
# ### Pre-train the Critic on Dataset

# %% [markdown]
# #### Only need full pretraining of critic when starting from scratch.  Otherwise, just finetune!

# %%
if old_checkpoint_num == 0:
    bs=3
    sz=256
    learn_gen=None
    gc.collect()
    data_crit = get_crit_data([name_gen, 'images'], bs=bs, sz=sz)
    data_crit.show_batch(rows=3, ds_type=DatasetType.Train, imgsize=3)
    learn_critic = colorize_crit_learner(data=data_crit, nf=256)
    learn_critic.callback_fns.append(partial(LearnerTensorboardWriter, base_dir=TENSORBOARD_PATH, name='CriticPreTrain-256px'))
    learn_critic.fit_one_cycle(7, 1e-3)
    learn_critic.save(crit_old_checkpoint_name)
# Out:
# /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/fastai/data_block.py:541: UserWarning: You are labelling your items with CategoryList.
# Your train set contained the following unknown labels, the corresponding items have been discarded.
# train
#   if getattr(ds, 'warn', False): warn(ds.warn)
# /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/fastai/data_block.py:541: UserWarning: You are labelling your items with CategoryList.
# Your valid set contained the following unknown labels, the corresponding items have been discarded.
# train
#   if getattr(ds, 'warn', False): warn(ds.warn)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh_expand</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.106138</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.044045</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.024137</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.014743</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.009519</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.006348</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.004320</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Critic Training

# %%
bs=3
sz=512

# %%
data_crit = get_crit_data([name_gen, 'images'], bs=bs, sz=sz)
# Out:
# /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/fastai/data_block.py:541: UserWarning: You are labelling your items with CategoryList.
# Your train set contained the following unknown labels, the corresponding items have been discarded.
# train
#   if getattr(ds, 'warn', False): warn(ds.warn)
# /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/fastai/data_block.py:541: UserWarning: You are labelling your items with CategoryList.
# Your valid set contained the following unknown labels, the corresponding items have been discarded.
# train
#   if getattr(ds, 'warn', False): warn(ds.warn)

# %%
data_crit.show_batch(rows=3, ds_type=DatasetType.Train, imgsize=3)

# %%
learn_critic = colorize_crit_learner(data=data_crit, nf=256).load(crit_old_checkpoint_name, with_opt=False)

# %%
learn_critic.callback_fns.append(partial(LearnerTensorboardWriter, base_dir=TENSORBOARD_PATH, name='CriticPreTrain-512px'))

# %%
learn_critic.fit_one_cycle(4, 1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh_expand</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_critic.save(crit_new_checkpoint_name)

# %% [markdown]
# ### GAN

# %%
learn_crit=None
learn_gen=None
gc.collect()
# Out:
# 77

# %%
lr=2e-5
sz=512
bs=3

# %%
data_crit = get_crit_data([name_gen, 'images'], bs=bs, sz=sz)
# Out:
# /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/fastai/data_block.py:541: UserWarning: You are labelling your items with CategoryList.
# Your train set contained the following unknown labels, the corresponding items have been discarded.
# train
#   if getattr(ds, 'warn', False): warn(ds.warn)
# /home/cecuser/anaconda3/envs/colorproj/lib/python3.6/site-packages/fastai/data_block.py:541: UserWarning: You are labelling your items with CategoryList.
# Your valid set contained the following unknown labels, the corresponding items have been discarded.
# train
#   if getattr(ds, 'warn', False): warn(ds.warn)

# %%
learn_crit = colorize_crit_learner(data=data_crit, nf=256).load(crit_new_checkpoint_name, with_opt=False)

# %%
learn_gen = gen_learner_wide(data=data_gen, gen_loss=FeatureLoss(), nf_factor=nf_factor).load(gen_old_checkpoint_name, with_opt=False)

# %%
switcher = partial(AdaptiveGANSwitcher, critic_thresh=0.65)
learn = GANLearner.from_learners(learn_gen, learn_crit, weights_gen=(1.0,1.5), show_img=False, switcher=switcher,
                                 opt_func=partial(optim.Adam, betas=(0.,0.9)), wd=1e-3)
learn.callback_fns.append(partial(GANDiscriminativeLR, mult_lr=5.))
learn.callback_fns.append(partial(GANTensorboardWriter, base_dir=TENSORBOARD_PATH, name='GanLearner', visual_iters=50))
learn.callback_fns.append(partial(GANSaveCallback, learn_gen=learn_gen, filename=gen_new_checkpoint_name, save_iters=50))

# %% [markdown]
# #### Instructions:
# Find the checkpoint just before where glitches start to be introduced.  This is all very new so you may need to play around with just how far you go here with keep_pct.

# %%
learn.data = get_data(sz=sz, bs=bs, keep_pct=0.1)
learn_gen.freeze_to(-1)
learn.fit(10,lr)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>gen_loss</th>
#       <th>disc_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>65.524445</td>
#       <td>0.752767</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>26.188803</td>
#       <td>2.578756</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>13.779061</td>
#       <td>0.693074</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>8.128856</td>
#       <td>0.693317</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.136219</td>
#       <td>0.886209</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.425237</td>
#       <td>0.692833</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.418806</td>
#       <td>0.691920</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.780820</td>
#       <td>0.688017</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.381971</td>
#       <td>0.693144</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.337942</td>
#       <td>2.163749</td>
#       <td>00:46</td>
#     </tr>
#   </tbody>
# </table>
